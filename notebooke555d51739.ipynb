# %%
#importer les librairies
import numpy as np
import  pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
Data=pd.read_csv('/kaggle/input/jobs-in-data/jobs_in_data.csv')
Data.duplicated().sum()
Data.drop_duplicates(inplace=True)
Data.drop(['salary','work_year'],axis=1, inplace=True)

# %%
Data
# Out:
#                      job_title                    job_category  \
# 0         Data DevOps Engineer                Data Engineering
# 1               Data Architect  Data Architecture and Modeling
# 2               Data Architect  Data Architecture and Modeling
# 3               Data Scientist       Data Science and Research
# 4               Data Scientist       Data Science and Research
# ...                        ...                             ...
# 9350           Data Specialist    Data Management and Strategy
# 9351            Data Scientist       Data Science and Research
# 9352  Principal Data Scientist       Data Science and Research
# 9353            Data Scientist       Data Science and Research
# 9354     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary_in_usd employee_residence experience_level  \
# 0                EUR          95012            Germany        Mid-level
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy of your DataFrame to avoid modifying the original
data_encoded = Data.copy()

# Iterate through each column in the DataFrame
for column in data_encoded.columns:
    if data_encoded[column].dtype == 'object':  # Check if the column is of object type (categorical)
        # Instantiate LabelEncoder
        label_encoder = LabelEncoder()
        # Fit and transform the column
        data_encoded[column] = label_encoder.fit_transform(data_encoded[column])

# %%
from sklearn.preprocessing import StandardScaler

salary_column = data_encoded['salary_in_usd']

# Instantiate StandardScaler
scaler = StandardScaler()

# Fit and transform the 'salary_in_usd' column
data_encoded['salary_in_usd'] = scaler.fit_transform(salary_column.values.reshape(-1, 1))

#from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#data['salary_in_usd_normalized'] = scaler.fit_transform(data['salary_in_usd'].values.reshape(-1, 1))

# %%
data_encoded
# Out:
#       job_title  job_category  salary_currency  salary_in_usd  \
# 0            42             4                5      -0.769606
# 1            41             3               10       0.596829
# 2            41             3               10      -0.968020
# 3            69             7               10       0.987291
# 4            69             7               10      -0.795316
# ...         ...           ...              ...            ...
# 9350         71             5               10       0.281456
# 9351         69             7               10       3.990840
# 9352        114             7               10       0.071208
# 9353         69             7               10      -0.619608
# 9354         21             2               10      -0.694697
#
#       employee_residence  experience_level  employment_type  work_setting  \
# 0                     29                 2                2             0
# ...

# %%
X=data_encoded.drop(['salary_in_usd'],axis=1)
Y=data_encoded['salary_in_usd']

# %%
#Diviser le dataset(20% pour le test)

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# Create a linear regression model
linear_reg = LinearRegression()

# Train the model
linear_reg.fit(X_train, Y_train)

# Predict on the test set
y_pred_linear = linear_reg.predict(X_test)

# %%
# Import necessary libraries
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics for each model
evaluation_metrics = {}

# Linear Regression
evaluation_metrics['Linear Regression'] = {
    'MAE': mean_absolute_error(Y_test, y_pred_linear),
    'MSE': mean_squared_error(Y_test, y_pred_linear),
    'RMSE': np.sqrt(mean_squared_error(Y_test, y_pred_linear)),
    'R2': r2_score(Y_test, y_pred_linear)
}
for model, metrics in evaluation_metrics.items():
    print(f"Evaluation metrics for {model}:")
    print(f"  MAE: {metrics['MAE']}")
    print(f"  MSE: {metrics['MSE']}")
    print(f"  RMSE: {metrics['RMSE']}")
    print(f"  R2: {metrics['R2']}")
    print()
# Out:
# Evaluation metrics for Linear Regression:
#   MAE: 0.6461279144184191
#   MSE: 0.6868926351073559
#   RMSE: 0.828789861851215
#   R2: 0.279133543865587

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a decision tree model
decision_tree = DecisionTreeRegressor()

# Train the model
decision_tree.fit(X_train, Y_train)

# Predict on the test set
y_pred_decision_tree = decision_tree.predict(X_test)

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_decision_tree = mean_absolute_error(Y_test, y_pred_decision_tree)
mse_decision_tree = mean_squared_error(Y_test, y_pred_decision_tree)
rmse_decision_tree = np.sqrt(mse_decision_tree)
r2_decision_tree = r2_score(Y_test, y_pred_decision_tree)

# Print evaluation metrics
print("Evaluation metrics for Decision Tree:")
print(f"  MAE: {mae_decision_tree}")
print(f"  MSE: {mse_decision_tree}")
print(f"  RMSE: {rmse_decision_tree}")
print(f"  R2: {r2_decision_tree}")
# Out:
# Evaluation metrics for Decision Tree:
#   MAE: 0.6342878605306165
#   MSE: 0.6753721073311015
#   RMSE: 0.8218102623666254
#   R2: 0.29122387881228295

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a random forest model
random_forest = RandomForestRegressor()

# Train the model
random_forest.fit(X_train, Y_train)

# Predict on the test set
y_pred_random_forest = random_forest.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_random_forest = mean_absolute_error(Y_test, y_pred_random_forest)
mse_random_forest = mean_squared_error(Y_test, y_pred_random_forest)
rmse_random_forest = np.sqrt(mse_random_forest)
r2_random_forest = r2_score(Y_test, y_pred_random_forest)

# Print evaluation metrics
print("Evaluation metrics for Random Forest:")
print(f"  MAE: {mae_random_forest}")
print(f"  MSE: {mse_random_forest}")
print(f"  RMSE: {rmse_random_forest}")
print(f"  R2: {r2_random_forest}")
# Out:
# Evaluation metrics for Random Forest:
#   MAE: 0.6152903744307209
#   MSE: 0.6256924437043463
#   RMSE: 0.7910072336612013
#   R2: 0.3433607066514278

# %%
from sklearn.ensemble import RandomForestRegressor

# Create a random forest model
random_forest = RandomForestRegressor()

# Train the model
random_forest.fit(X_train, Y_train)

# Predict on the test set
y_pred_random_forest = random_forest.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_random_forest = mean_absolute_error(Y_test, y_pred_random_forest)
mse_random_forest = mean_squared_error(Y_test, y_pred_random_forest)
rmse_random_forest = np.sqrt(mse_random_forest)
r2_random_forest = r2_score(Y_test, y_pred_random_forest)

# Print evaluation metrics
print("Evaluation metrics for RandomForestRegressor:")
print(f"  MAE: {mae_random_forest}")
print(f"  MSE: {mse_random_forest}")
print(f"  RMSE: {rmse_random_forest}")
print(f"  R2: {r2_random_forest}")
# Out:
# Evaluation metrics for RandomForestRegressor:
#   MAE: 0.6159647686254659
#   MSE: 0.6264902062686342
#   RMSE: 0.7915113431080025
#   R2: 0.3425234866214518

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Create a gradient boosting model
gradient_boosting = GradientBoostingRegressor()

# Train the model
gradient_boosting.fit(X_train, Y_train)

# Predict on the test set
y_pred_gradient_boosting = gradient_boosting.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_gradient_boosting = mean_absolute_error(Y_test, y_pred_gradient_boosting)
mse_gradient_boosting = mean_squared_error(Y_test, y_pred_gradient_boosting)
rmse_gradient_boosting = np.sqrt(mse_gradient_boosting)
r2_gradient_boosting = r2_score(Y_test, y_pred_gradient_boosting)

# Print evaluation metrics
print("Evaluation metrics for GradientBoostingRegressor:")
print(f"  MAE: {mae_gradient_boosting}")
print(f"  MSE: {mse_gradient_boosting}")
print(f"  RMSE: {rmse_gradient_boosting}")
print(f"  R2: {r2_gradient_boosting}")
# Out:
# Evaluation metrics for GradientBoostingRegressor:
#   MAE: 0.5854893073984873
#   MSE: 0.5811494303135638
#   RMSE: 0.7623315750469501
#   R2: 0.3901068247016565

# %%
from sklearn.svm import SVR

# Create an SVM model
svm = SVR()

# Train the model
svm.fit(X_train, Y_train)

# Predict on the test set
y_pred_svm = svm.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_svm = mean_absolute_error(Y_test, y_pred_svm)
mse_svm = mean_squared_error(Y_test, y_pred_svm)
rmse_svm = np.sqrt(mse_svm)
r2_svm = r2_score(Y_test, y_pred_svm)

# Print evaluation metrics
print("Evaluation metrics for SVR:")
print(f"  MAE: {mae_svm}")
print(f"  MSE: {mse_svm}")
print(f"  RMSE: {rmse_svm}")
print(f"  R2: {r2_svm}")
# Out:
# Evaluation metrics for SVR:
#   MAE: 0.6452377867131422
#   MSE: 0.704065724907096
#   RMSE: 0.8390862440220885
#   R2: 0.2611110702618602

# %%
from sklearn.neural_network import MLPRegressor

# Create a neural network model
neural_network = MLPRegressor()

# Train the model
neural_network.fit(X_train, Y_train)

# Predict on the test set
y_pred_neural_network = neural_network.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_neural_network = mean_absolute_error(Y_test, y_pred_neural_network)
mse_neural_network = mean_squared_error(Y_test, y_pred_neural_network)
rmse_neural_network = np.sqrt(mse_neural_network)
r2_neural_network = r2_score(Y_test, y_pred_neural_network)

# Print evaluation metrics
print("Evaluation metrics for MLPRegressor:")
print(f"  MAE: {mae_neural_network}")
print(f"  MSE: {mse_neural_network}")
print(f"  RMSE: {rmse_neural_network}")
print(f"  R2: {r2_neural_network}")
# Out:
# Evaluation metrics for MLPRegressor:
#   MAE: 0.6913844403867904
#   MSE: 0.7394874177428337
#   RMSE: 0.8599345427082422
#   R2: 0.22393741475922235

# %%
from sklearn.neighbors import KNeighborsRegressor

# Create a KNN model
knn = KNeighborsRegressor()

# Train the model
knn.fit(X_train, Y_train)

# Predict on the test set
y_pred_knn = knn.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_knn = mean_absolute_error(Y_test, y_pred_knn)
mse_knn = mean_squared_error(Y_test, y_pred_knn)
rmse_knn = np.sqrt(mse_knn)
r2_knn = r2_score(Y_test, y_pred_knn)

# Print evaluation metrics
print("Evaluation metrics for KNeighborsRegressor:")
print(f"  MAE: {mae_knn}")
print(f"  MSE: {mse_knn}")
print(f"  RMSE: {rmse_knn}")
print(f"  R2: {r2_knn}")
# Out:
# Evaluation metrics for KNeighborsRegressor:
#   MAE: 0.6626078848917721
#   MSE: 0.7238194437825641
#   RMSE: 0.8507757893725961
#   R2: 0.24038032925019015

# %%
from xgboost import XGBRegressor
from sklearn.metrics import r2_score

# Create XGBRegressor model
xgb_model = XGBRegressor()

# Fit the model to the training data
xgb_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
xgb_pred = xgb_model.predict(test_pipelined)

# Compute R-squared score
xgb_r2 = r2_score(test_labels, xgb_pred)

print(f"R-squared score for XGBRegressor: {xgb_r2}")
# Out:
# R-squared score for XGBRegressor: 0.5002134986765976

# %%
from xgboost import XGBRegressor

# Create an XGBoost model
xgboost = XGBRegressor()

# Train the model
xgboost.fit(X_train, Y_train)

# Predict on the test set
y_pred_xgboost = xgboost.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_xgboost = mean_absolute_error(Y_test, y_pred_xgboost)
mse_xgboost = mean_squared_error(Y_test, y_pred_xgboost)
rmse_xgboost = np.sqrt(mse_xgboost)
r2_xgboost = r2_score(Y_test, y_pred_xgboost)

# Print evaluation metrics
print("Evaluation metrics for XGBoost:")
print(f"  MAE: {mae_xgboost}")
print(f"  MSE: {mse_xgboost}")
print(f"  RMSE: {rmse_xgboost}")
print(f"  R2: {r2_xgboost}")
# Out:
# Evaluation metrics for XGBoost:
#   MAE: 0.6093687555556427
#   MSE: 0.6162349839046296
#   RMSE: 0.7850063591491662
#   R2: 0.35328593394519536

# %%
from lightgbm import LGBMRegressor

# Create a LightGBM model
lightgbm = LGBMRegressor()

# Train the model
lightgbm.fit(X_train, Y_train)

# Predict on the test set
y_pred_lightgbm = lightgbm.predict(X_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Compute evaluation metrics
mae_lightgbm = mean_absolute_error(Y_test, y_pred_lightgbm)
mse_lightgbm = mean_squared_error(Y_test, y_pred_lightgbm)
rmse_lightgbm = np.sqrt(mse_lightgbm)
r2_lightgbm = r2_score(Y_test, y_pred_lightgbm)

# Print evaluation metrics
print("Evaluation metrics for LightGBM:")
print(f"  MAE: {mae_lightgbm}")
print(f"  MSE: {mse_lightgbm}")
print(f"  RMSE: {rmse_lightgbm}")
print(f"  R2: {r2_lightgbm}")
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 206
# [LightGBM] [Info] Number of data points in the train set: 4272, number of used features: 9
# [LightGBM] [Info] Start training from score 0.005668
# Evaluation metrics for LightGBM:
#   MAE: 0.5924130956262791
#   MSE: 0.5885646455852855
#   RMSE: 0.7671796696897576
#   R2: 0.38232485168113584

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Define the neural network architecture
model = Sequential([
    Dense(64, activation='softmax', input_shape=(X_train.shape[1],)),
    Dropout(0.5),  # Add dropout for regularization
    Dense(64, activation='softmax', input_shape=(X_train.shape[1],)),
    Dropout(0.5),  # Add dropout for regularization
    Dense(64, activation='softmax'),
    Dropout(0.5),  # Add dropout for regularization
    Dense(1)  # Output layer with single neuron for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

# Print the model summary
model.summary()

# Train the model
history = model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
loss, mae, mse = model.evaluate(X_test, Y_test)
print(f'Test loss: {loss}')
print(f'Test MAE: {mae}')
print(f'Test MSE: {mse}')
from sklearn.metrics import r2_score

# Predict on the test set
y_pred = model.predict(X_test)

# Compute R-squared
r2 = r2_score(Y_test, y_pred)
print(f'R2 Score: {r2}')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         4,160 │
# ...

# %%
#construire le modéle
regressor=LinearRegression()
regressor.fit(X_train,Y_train)
#faire des prédictions 
Y_pred=regressor.predict(X_test)
#Calcul des métrique d'évaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
# MAE (Mean Absolute Error)
mae = mean_absolute_error(Y_test, Y_pred)
# R² (Coefficient de détermination)
r2 = r2_score(Y_test, Y_pred)
print("RMSE:", rmse)
print("MAE:", mae)
print("R²:", r2)
# Out:
# RMSE: 0.828789861851215
# MAE: 0.6461279144184191
# R²: 0.279133543865587

# %%
data = Data.copy()
data
# Out:
#                      job_title                    job_category  \
# 0         Data DevOps Engineer                Data Engineering
# 1               Data Architect  Data Architecture and Modeling
# 2               Data Architect  Data Architecture and Modeling
# 3               Data Scientist       Data Science and Research
# 4               Data Scientist       Data Science and Research
# ...                        ...                             ...
# 9350           Data Specialist    Data Management and Strategy
# 9351            Data Scientist       Data Science and Research
# 9352  Principal Data Scientist       Data Science and Research
# 9353            Data Scientist       Data Science and Research
# 9354     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary_in_usd employee_residence experience_level  \
# 0                EUR          95012            Germany        Mid-level
# ...

# %%
# Count the occurrences of each job title
job_title_counts = data['job_title'].value_counts()

# Identify job titles with 3 or fewer occurrences
job_title_cat_other = job_title_counts[job_title_counts <= 3].index

# Replace rare job titles with 'other'
data['job_title'] = data['job_title'].apply(lambda x: 'other' if x in job_title_cat_other else x)


# Count the occurrences of each employee residence
emp_res_counts = data['employee_residence'].value_counts()

# Identify employee residences with 2 or fewer occurrences
emp_res_cat_other = emp_res_counts[emp_res_counts <= 2].index

# Replace rare employee residences with 'other'
data['employee_residence'] = data['employee_residence'].apply(lambda x: 'other' if x in emp_res_cat_other else x)


# Count the occurrences of each company location
com_loc_counts = data['company_location'].value_counts()

# Identify company locations with 2 or fewer occurrences
com_loc_cat_other = com_loc_counts[com_loc_counts <= 2].index

# Replace rare company locations with 'other'
data['company_location'] = data['company_location'].apply(lambda x: 'other' if x in com_loc_cat_other else x)

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(data,test_size=0.2,random_state=38)
train = data.drop('salary_in_usd',axis=1)
train_labels = data['salary_in_usd'].copy()
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('one_hot_cat',OneHotEncoder())
])
 

train_pipelined = pipeline.fit_transform(train)
train_pipelined.shape
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

lr_model.fit(train_pipelined,train_labels)
rand_features = train.iloc[:5]
rand_labels = train_labels.iloc[:5]

rand_pipelined = pipeline.transform(rand_features)
lr_model.predict(rand_pipelined)
list(rand_labels)
test = test_data.drop('salary_in_usd',axis=1)
test_labels = test_data['salary_in_usd'].copy()
test_pipelined = pipeline.transform(test)
lr_pred = lr_model.predict(test_pipelined)
from sklearn.metrics import mean_squared_error

lr_model.score(test_pipelined,test_labels)
# Out:
# 0.42982226245822786

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

# Create GradientBoostingRegressor model
gb_model = GradientBoostingRegressor()

# Fit the model to the training data
gb_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
gb_pred = gb_model.predict(test_pipelined)

# Compute R-squared score
gb_r2 = r2_score(test_labels, gb_pred)

print(f"R-squared score for GradientBoostingRegressor: {gb_r2}")
# Out:
# R-squared score for GradientBoostingRegressor: 0.4256647191213051

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# Create RandomForestRegressor model
rf_model = RandomForestRegressor()

# Fit the model to the training data
rf_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
rf_pred = rf_model.predict(test_pipelined)

# Compute R-squared score
rf_r2 = r2_score(test_labels, rf_pred)

print(f"R-squared score for RandomForestRegressor: {rf_r2}")
# Out:
# R-squared score for RandomForestRegressor: 0.5236768831049924

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

# Create KNN model
knn_model = KNeighborsRegressor()

# Fit the model to the training data
knn_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
knn_pred = knn_model.predict(test_pipelined)

# Compute R-squared score
knn_r2 = r2_score(test_labels, knn_pred)

print(f"R-squared score for KNN: {knn_r2}")
# Out:
# R-squared score for KNN: 0.4178148734554935

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# Create DecisionTreeRegressor model
dt_model = DecisionTreeRegressor()

# Fit the model to the training data
dt_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
dt_pred = dt_model.predict(test_pipelined)

# Compute R-squared score
dt_r2 = r2_score(test_labels, dt_pred)

print(f"R-squared score for DecisionTreeRegressor: {dt_r2}")
# Out:
# R-squared score for DecisionTreeRegressor: 0.5317503404674067

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score

# Define the ANN architecture
model = Sequential([
    Dense(64, activation='softmax', input_shape=(train_pipelined.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer with single neuron for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

# Print the model summary
model.summary()

# Fit the model to the training data
history = model.fit(train_pipelined, train_labels, epochs=50, batch_size=35, validation_split=0.2)

# Evaluate the model on the test set
loss, mae, mse = model.evaluate(test_pipelined, test_labels)
print(f'Test loss: {loss}')
print(f'Test MAE: {mae}')
print(f'Test MSE: {mse}')

# Make predictions on the test set
predictions = model.predict(test_pipelined)

# Calculate R-squared score
r_squared = r2_score(test_labels, predictions)
print(f'R-squared score on test set: {r_squared}')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_63 (Dense)                │ (None, 64)             │        12,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_64 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_65 (Dense)                │ (None, 32)             │         2,080 │
# ...

# %%
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score

# Create LGBMRegressor model
lgbm_model = LGBMRegressor()

# Fit the model to the training data
lgbm_model.fit(train_pipelined, train_labels)

# Make predictions on the test data
lgbm_pred = lgbm_model.predict(test_pipelined)

# Compute R-squared score
lgbm_r2 = r2_score(test_labels, lgbm_pred)

print(f"R-squared score for LGBMRegressor: {lgbm_r2}")
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001387 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 142
# [LightGBM] [Info] Number of data points in the train set: 5341, number of used features: 71
# [LightGBM] [Info] Start training from score 146258.409099
# R-squared score for LGBMRegressor: 0.47090916810281325

# %%
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()

tree_reg.fit(train_pipelined,train_labels)
# tree_pred = tree_reg.predict(test_pipelined)
tree_reg.score(test_pipelined,test_labels)
# Out:
# 0.5317503404674067

# %%
from joblib import dump

# Sauvegarder le modèle
dump(regressor, 'modele_regression.pkl')
# Out:
# ['modele_regression.pkl']
